# %% [markdown]
# <a href="https://colab.research.google.com/github/dadewale/Davidswork/blob/main/notebooks/DTS201_Week1_PH_Student_Centred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Week 1 Practical Report
#
# **Course Code:** DTS 201
#
# **Student Name:** OLUWOLE DAVID ADEWALE
#
# **Reg No:** 202590001561HA
#
# **Date:** 24th November, 2025

# %% [markdown]
# # DTS 201 – Introduction to Data Science
# ## Week 1 Practical (PH): Exploring Sample Datasets and Data Types
#
# **Instructor:** Dr. Sakinat Folorunso
#
# **Title:** Associate Professor of AI Systems and FAIR Data
# Department: Computer Sciences, Olabisi Onabanjo University, Ago-Iwoye, Ogun State, Nigeria
#
# **Course Code:** DTS 201
# **Practical Week:** 1 – Introduction to Data and File Types
#
# ---
#
# ### 🎯 Practical Learning Objectives
#
# By the end of this practical session, you should be able to:
#
# - Open and explore sample datasets stored in **CSV** and **Excel** formats.
# - Inspect the **rows, columns, data types, and basic structure** of a dataset.
# - Distinguish between **structured**, **semi-structured**, and **unstructured** data using real examples.
# - Describe, in your own words, what type of data each sample file represents and why.
#
# > ✅ This notebook is **student-centred**: you will run the code, modify it, and answer short reflection questions in the provided spaces.

# %% [markdown]
# ## 1. Getting Started: Where Is Your Data?
#
# You can run this notebook in one of two common ways:
#
# 1. **Google Colab**
#    - Upload your dataset files (e.g., `.csv`, `.xlsx`) to your Google Drive or directly to Colab.
#    - If your dataset is saved in Google Drive, you’ll need to **mount Drive first**.
# 2. **Local Jupyter Notebook (on your laptop)**
#    - Save the dataset files in a folder on your computer.
#    - You will need to provide the **correct file path** to the dataset (e.g., `"data/students_scores.csv"`).
#
# > ✏️ You do **not** need to have a specific dataset yet. Your lecturer may provide sample files such as `students_scores.csv` or `sales_data.xlsx`. You can also practice with any simple CSV/Excel file you already have.

# %% [markdown]
# ### 1.1 (Optional) Mounting Google Drive in Colab

# %%
# NOTE: Run this cell ONLY if you are using Google Colab and your data is stored in Google Drive.

# Import the drive module from google.colab to allow access to Google Drive
from google.colab import drive  # Provides tools to connect Colab to your Google Drive

# Mount your Google Drive so that it appears as a folder within the Colab environment
drive.mount('/content/drive')  # After running, follow the on-screen instructions to authorize access

# After mounting, your files will be accessible under the path '/content/drive/MyDrive'
# Example: data_path = '/content/drive/MyDrive/Datasets/students_scores.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Importing Required Libraries

# %%
# Import the pandas library for working with tabular data (rows and columns)
import pandas as pd

# Import numpy for numerical operations (we may need it later)
import numpy as np

# Import matplotlib for basic plotting (optional for this week but useful generally)
import matplotlib.pyplot as plt

# Configure matplotlib so that any plots appear inside the notebook
# %matplotlib inline

# %% [markdown]
# ## 3. Exploring a Sample CSV Dataset
#
# In this section, you will:
#
# - Load a sample **CSV** file into a pandas DataFrame.
# - Look at the first few rows.
# - Inspect the structure of the data (columns, types).
#
# > 🔧 **Instruction:**
# > - Replace `"students_scores.csv"` with the actual name of your CSV file.
# > - Make sure the file is in the same folder as this notebook, or provide the full path.

# %%
# Define the path or file name of your CSV dataset
# If your file is in the same folder as this notebook, you can just use the file name
# Example: data_path_csv = 'students_scores.csv'
# If your file is in Google Drive (after mounting): data_path_csv = '/content/drive/MyDrive/YourFolderName/students_scores.csv'
data_path_csv = '/content/drive/MyDrive/Colab_Notebooks/students_scores.csv'

# Load the CSV file into a pandas DataFrame
df_csv = pd.read_csv(data_path_csv)  # Reads the CSV file and stores the data in the variable 'df_csv'

# Display the first 5 rows of the dataset
df_csv.head()  # Helps you quickly see what the data looks like (columns and sample rows)
# Out:
#    StudentID     Name  MathScore  ScienceScore Grade
# 0        101    Alice         85            79     B
# 1        102      Bob         92            88     A
# 2        103  Charlie         78            82     C
# 3        104    David         88            90     B
# 4        105      Eve         95            91     A

# %% [markdown]
# After running the cell above, you can compare the outputted directory with the actual location of your `students_scores.csv` file. This should help you determine if the file is where Python expects it to be, or if you need to provide a more specific path.

# %% [markdown]
# > ✏️ **Student Task 1:**
# > - What does each **row** represent in this dataset (e.g., a student, a transaction, a product)?
# > - Name at least **three columns** and say what kind of information they contain (e.g., score, age, grade).
# > - Write your answers in a separate markdown cell or on your answer sheet.

# %% [markdown]
# Solution to Student Task 1
#
# * What does each row represent in this dataset?
#
#
# Each row represents one individual student and their associated academic performance. We know this because the StudentID and Name change for every row, but the columns remain the same.
#
# * Name at least three columns and say what kind of information they contain.
#
#
# Name: Contains text (String) data representing the identity of the student.
#
# MathScore: Contains numerical (Integer) data representing the student's marks in Mathematics.
#
# Grade: Contains categorical (Text/Char) data summarizing the student's overall performance (e.g., 'A', 'B').

# %% [markdown]
# ### 3.1 Understanding the Structure of the CSV Dataset

# %%
# Check the number of rows and columns in the CSV dataset
df_csv.shape  # Returns a tuple: (number_of_rows, number_of_columns)
# Out:
# (5, 5)

# %%
# Display information about the CSV dataset
# This includes column names, data types, and how many non-missing values are in each column
df_csv.info()  # Helps you understand the structure and quality of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StudentID     5 non-null      int64
#  1   Name          5 non-null      object
#  2   MathScore     5 non-null      int64
#  3   ScienceScore  5 non-null      int64
#  4   Grade         5 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 332.0+ bytes

# %%
# Display the data types of each column explicitly
df_csv.dtypes  # Shows whether each column is integer, float, object (text), etc.
# Out:
# StudentID        int64
# Name            object
# MathScore        int64
# ScienceScore     int64
# Grade           object
# dtype: object

# %% [markdown]
# > ✏️ **Student Reflection 2:**
# > - How many rows and columns does your CSV dataset have?
# > - Which columns are **numerical** (e.g., integers, floats)?
# > - Which columns are **categorical/text** (e.g., names, categories)?

# %% [markdown]
# Solution to Student Reflection 2
#
#
#
# *   The CSV dataset (`df_csv`) has **5 rows** and **5 columns**.
#
# *   **Numerical columns** are:
#     *   `StudentID` (int64)
#     *   `MathScore` (int64)
#     *   `ScienceScore` (int64)
#
# *   **Categorical/text columns** are:
#     *   `Name` (object)
#     *   `Grade` (object)

# %% [markdown]
# ## 4. Data Types: Structured, Semi-Structured, and Unstructured
#
# Before we explore Excel files, let’s recall three important categories of data:
#
# 1. **Structured Data**
#    - Organized in a clear tabular format (rows and columns).
#    - Each column has a defined data type (e.g., number, text, date).
#    - Examples: Excel tables, CSV files, relational databases.
#
# 2. **Semi-Structured Data**
#    - Contains some organization but not strictly tabular.
#    - Uses tags or markers (e.g., key–value pairs).
#    - Examples: JSON, XML, some log files.
#
# 3. **Unstructured Data**
#    - Has no fixed format or layout.
#    - Examples: raw text documents, images, audio, video.
#
# > 💡 In this practical, your CSV and Excel files are examples of **structured data** because they are arranged in rows and columns.

# %% [markdown]
# ## 5. Exploring a Sample Excel Dataset
#
# Now, we will repeat the process with an **Excel** file (`.xlsx`).
#
# > 🔧 **Instruction:**
# > - Replace `"sales_data.xlsx"` with your actual Excel file name.
# > - If the file has multiple sheets, you can specify the sheet name with the `sheet_name` argument.

# %%
import pandas as pd
import os

# Sample data for sales
data = {
    'ProductID': ['P001', 'P002', 'P003', 'P004', 'P005'],
    'Category': ['Electronics', 'Clothing', 'Home', 'Electronics', 'Books'],
    'SalesAmount': [1200, 350, 800, 1500, 50],
    'Quantity': [2, 7, 1, 3, 10],
    'Date': pd.to_datetime(['2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09'])
}

# Create a DataFrame
df_sample_sales = pd.DataFrame(data)

# Define the path to save the Excel file in your Google Drive
output_directory = '/content/drive/MyDrive/Colab_Notebooks/'
output_filename = 'david_oluwole.xlsx'
output_path = os.path.join(output_directory, output_filename)

# Create the directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Save the DataFrame to an Excel file
df_sample_sales.to_excel(output_path, index=False, engine='openpyxl')

print(f"Sample 'david_oluwole.xlsx' saved to: {output_path}")
print("Please update the 'data_path_excel' variable in the next relevant cell with this path and then run that cell.")
# Out:
# Sample 'david_oluwole.xlsx' saved to: /content/drive/MyDrive/Colab_Notebooks/david_oluwole.xlsx
# Please update the 'data_path_excel' variable in the next relevant cell with this path and then run that cell.

# %%
# Define the path or file name of your Excel dataset
# Example: data_path_excel = 'sales_data.xlsx'
data_path_excel = '/content/drive/MyDrive/Colab_Notebooks/david_oluwole.xlsx'  # TODO: change this to your actual Excel file name and verify path

# Load the Excel file into a pandas DataFrame
# By default, pandas reads the first sheet in the Excel file
df_excel = pd.read_excel(data_path_excel, engine='openpyxl')  # Reads the Excel file and stores the data in 'df_excel', specifying the engine

# Display the first 5 rows of the Excel dataset
df_excel.head()  # Helps you check the structure and contents of the Excel data
# Out:
#   ProductID     Category  SalesAmount  Quantity       Date
# 0      P001  Electronics         1200         2 2023-01-05
# 1      P002     Clothing          350         7 2023-01-06
# 2      P003         Home          800         1 2023-01-07
# 3      P004  Electronics         1500         3 2023-01-08
# 4      P005        Books           50        10 2023-01-09

# %% [markdown]
# > ✏️ **Student Task 3:**
# > - Compare the Excel dataset with the CSV dataset you loaded earlier.
# > - How are they similar? How are they different (e.g., columns, data types, context)?

# %% [markdown]
# Solution to Student Task 3
#
# **Comparison of Excel Dataset (`df_excel`) with CSV Dataset (`df_csv`):**
#
# **Similarities:**
# *   Both datasets are examples of **structured data**, meaning they are organized in a clear tabular format with rows and columns.
# *   Both were successfully loaded and inspected using the **pandas library** (`pd.read_csv()` and `pd.read_excel()`).
# *   Both contain a mix of **numerical data** (e.g., `int64` for scores/amounts/quantity) and **categorical/text data** (e.g., `object` for names/categories/grades).
# *   Basic inspection methods like `.head()`, `.shape`, `.info()`, and `.dtypes` can be applied to both to understand their structure.
#
# **Differences:**
# *   **Context/Content:** The CSV dataset (`df_csv`) focuses on **student academic performance** (e.g., `StudentID`, `Name`, `MathScore`, `ScienceScore`, `Grade`), whereas the Excel dataset (`df_excel`) represents **product sales transactions** (e.g., `ProductID`, `Category`, `SalesAmount`, `Quantity`, `Date`).
# *   **File Format:** One is a Comma Separated Values (`.csv`) file, and the other is an Excel Workbook (`.xlsx`) file.
# *   **Specific Data Types/Columns:**
#     *   `df_csv` has numerical columns like `StudentID`, `MathScore`, and `ScienceScore`.
#     *   `df_excel` has numerical columns like `SalesAmount` and `Quantity`, but also includes a `Date` column which is a `datetime64[ns]` type, not present in `df_csv`.

# %% [markdown]
# ### 5.1 Inspecting the Structure of the Excel Dataset

# %%
# Check the number of rows and columns in the Excel dataset
df_excel.shape  # Returns (number_of_rows, number_of_columns) for the Excel data
# Out:
# (5, 5)

# %%
# Display detailed information about the Excel dataset
df_excel.info()  # Shows column names, data types, and non-null counts for each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    5 non-null      object
#  1   Category     5 non-null      object
#  2   SalesAmount  5 non-null      int64
#  3   Quantity     5 non-null      int64
#  4   Date         5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 332.0+ bytes

# %%
# Display the data types of each column in the Excel dataset
df_excel.dtypes  # Shows whether each column is integer, float, object (text), etc.
# Out:
# ProductID              object
# Category               object
# SalesAmount             int64
# Quantity                int64
# Date           datetime64[ns]
# dtype: object

# %% [markdown]
# > ✏️ **Student Reflection 4:**
# > - Are the data types in the Excel dataset mostly similar to those in the CSV file?
# > - Identify one column that you think is **categorical** and one that is **numerical** in the Excel dataset.

# %% [markdown]
# Solution to Reflection 4
#
# *   The data types in the Excel dataset (`df_excel`) are **mostly similar** to those in the CSV file (`df_csv`), both containing `int64` (numerical) and `object` (categorical/text) types. However, the Excel dataset also includes a `datetime64[ns]` type for the 'Date' column, which was not present in the CSV file.
#
# *   **One categorical column** in the Excel dataset: `Category` (or `ProductID`)
#
# *   **One numerical column** in the Excel dataset: `SalesAmount` (or `Quantity`)

# %% [markdown]
# ## 6. Classifying Datasets by Type (Activity)
#
# Using the definitions from Section 4, classify the following as **structured**, **semi-structured**, or **unstructured**:
#
# 1. The CSV dataset you loaded (`df_csv`).
# 2. The Excel dataset you loaded (`df_excel`).
# 3. A folder of .jpg images.
# 4. A collection of WhatsApp chat exports in `.txt` format.
# 5. A JSON file containing product data (e.g., from an API).
#
# > ✏️ **Student Task 5:**
# > - For each of the five items above, write:
# >   - The **type of data** (structured / semi-structured / unstructured).
# >   - A **one-line justification** of your choice.

# %% [markdown]
# Solution to Student Task 5
#
# 1.  **The CSV dataset you loaded (`df_csv`):**
#     *   **Type:** Structured Data
#     *   **Justification:** It is organized in a clear tabular format (rows and columns) with defined data types.
#
# 2.  **The Excel dataset you loaded (`df_excel`):**
#     *   **Type:** Structured Data
#     *   **Justification:** It is organized in a clear tabular format (rows and columns) with defined data types.
#
# 3.  **A folder of .jpg images:**
#     *   **Type:** Unstructured Data
#     *   **Justification:** Images have no fixed format or layout that allows for easy querying of their content.
#
# 4.  **A collection of WhatsApp chat exports in `.txt` format:**
#     *   **Type:** Unstructured Data
#     *   **Justification:** Raw text documents have no fixed format or layout that can be directly queried.
#
# 5.  **A JSON file containing product data (e.g., from an API):**
#     *   **Type:** Semi-structured Data
#     *   **Justification:** It uses tags and key-value pairs for organization but is not strictly tabular.

# %% [markdown]
# ## 7. Summary and Reflection (Week 1 PH)
#
# In this practical, you:
#
# - Loaded **CSV** and **Excel** files into pandas DataFrames.
# - Used `.head()`, `.info()`, `.shape`, and `.dtypes` to understand the structure of your data.
# - Reviewed the concepts of **structured**, **semi-structured**, and **unstructured** data.
# - Practised classifying different real-world data examples by type.
#
# > 🧠 **Final Reflection (Write in your own words):**
# > - What was the most **surprising** thing you learned about data formats today?
# > - Which method or function (e.g., `.head()`, `.info()`) do you think you will use the most in future practicals, and why?

# %% [markdown]
# *   **Most surprising thing learned about data formats:**
#     It was surprising to learn that `.xlsx` files, despite being a single file, are internally structured like 'zip' archives. This explains why simply renaming a `.txt` file to `.xlsx` doesn't work, and why errors like `BadZipFile` can occur if the file isn't properly saved by an Excel program.
#
# *   **Method or function to use most in future practicals and why:**
#     I think I will use `.info()` the most in future practicals. It provides a quick and comprehensive overview of the dataset's structure, including column names, the number of non-null values, and crucial data types, all of which are essential for understanding the data's quality and planning initial cleaning or analysis steps. Knowing the data types upfront helps prevent many common errors.
